# %%
"""Question 1"""
userFBS = int(input("What is your fasting blood sugar?"))
if userFBS >= 99:
    print("Your blood sugar is higher than normal range.")
elif userFBS < 99:
    print("Your blood sugar is at or under the normal range.")
else:
    print("You may need to run this again.....")
# Out:
# What is your fasring blood sugar?55
# Your blood sugar is at or under the normal range.

# %%
"""Question 2"""

from random import sample

for i in range(0,100):

    a = sample(['1','2','3'],1)
    b = sample(['1','2','3'],1)
    
    print(a, b)

#    file_a = open(file='file1.txt', mode='a')
#    file_b = open(file='file2.txt', mode='a')
    file_a = open('file1.txt', 'a')
    file_b = open('file2.txt', 'a')
    
    file_a.write('a')
    file_b.write('b')
    
    
    
file_a.close()
file_b.close()



"""
for i in range(0,10):
        
        x = int(i)
        
        file_a = open('file1.txt', 'r')
        file_b = open('file2.txt', 'r')
        
        if (file_a.readlines(x) == file_b.readlines(x)):
            print(file_a.readlines(x))
            print(file_b.readlines(x))
            print("Success!")
            i = i + 1
        else:
            i = i + 1
            """
file_a = open('file1.txt', 'r')
file_b = open('file2.txt', 'r')

for i in range(0, 100):
    
    Val1 = file_a.readline(i)
    Val2 = file_b.readline(i)
    print(Val1 + " " + Val2 )
    print(i)
    
    if Val1 == Val2:
        print("Success!")
    else:
        print("Not Success")
        


 ################## your code here ###################
 ## you need to
 ## 1. write a for loop to read the files line by line
 ## and compare the values


 #######################################################

# %%
"""Question 3"""
file = open('sample-file.txt', 'r')
counts = 0

for i in file:
    for q in file:
        counts = counts + 1
    print(counts)

# %%
"""Question 4"""
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('student.csv')

data = data[['internet', 'grade']]

data2 = data.groupby('internet').mean().reset_index()


internet = data2["internet"].reset_index()
grade = data2['grade'].reset_index()

mean = grade.mean
print(data2)

print(internet)
print(grade)

data2.plot(kind = 'bar', x = 'internet', y = 'grade')

# %%
"""Question 5"""

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('student.csv')

data = data[['grade', 'studytime']]

studytimeave = data.groupby('studytime').mean().reset_index()

one = data['studytime']
print(studytimeave)




studytimeave.plot(kind = 'line', x = 'studytime', y = 'grade')

# %%
"""Question 6"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

crime = pd.read_csv('crime.csv')

crime = crime[['PctPopUnderPov', 'ViolentCrimesPerPop']]

crimeReshaped = np.array(crime['ViolentCrimesPerPop']).reshape(-1,1)
povertyReshaped = np.array(crime['PctPopUnderPov']).reshape(-1,1)

plt.xlabel('Violent Crimes per Thousand')
plt.ylabel('Percentage of pop in Poverty')
plt.scatter(povertyReshaped, crimeReshaped, label = 'Violent Crime relative to population ')
#crimeScaled.plot( kind = 'scatter', x = 'PctPopUnderPov', y = 'crimeScaled')
plt.legend()

plt.show()
print(crime)
print(crimeScaled)

# %%
"""Question 8"""

import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('student.csv')

data = data[['grade', 'studytime']]

studytimeave = data.groupby('studytime').mean().reset_index()

lessthanthreearray = list(())
morethanthreearray = list(())

def lessthanthree(lessthanthreearray):
    
    for i in data['studytime']:
        keys = data.get('studytime', 1)
        
        if (keys<=3):
            morethanthreearray.append(data['studytime'])
        else: 
            lessthanthreearray.append(data['studytime'])
one = data['studytime']
print(studytimeave)

lessthanthree(lessthanthreearray)
